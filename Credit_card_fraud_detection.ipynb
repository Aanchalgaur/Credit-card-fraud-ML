# %% [markdown]
# <a href="https://colab.research.google.com/github/Aanchalgaur/Credit-card-fraud-ML/blob/main/Credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# dataset : https://www.kaggle.com/mlg-ulb/creditcardfraud/version/3

# %% [markdown]
# ## importing libraries and datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv('/content/creditcard.csv')

# %% [markdown]
# ## data exploration

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]>

# %%
#statistical summary
dataset.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Dealing with missing values

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
dataset.isnull().values.sum()
# Out:
# 0

# %%
dataset.columns[dataset.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
# %of null values
null_percent = dataset.isnull().sum() / dataset.shape[0] * 100

# %%
null_percent
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %% [markdown]
# ## incoding categorial data

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# no categorial data

# %% [markdown]
# ## Countplot

# %%
sns.countplot(dataset['Class'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#non fraud transcitions
(dataset.Class==0).sum()
# Out:
# 284315

# %%
#fraud cases
(dataset.Class==1).sum()
# Out:
# 492

# %% [markdown]
# ## Correlation matrix and heatmap

# %%
dataset_2 = dataset.drop(columns='Class')

# %%
dataset_2.corrwith(dataset['Class']).plot.bar(
    figsize=(16,9), title= 'Correlated with Class' , grid=True
)

# %%
corr= dataset.corr()

# %%
plt.figure(figsize=(25,25))
ax= sns.heatmap(corr, annot=True, linewidths=2)

# %% [markdown]
# ## splitting the dataset

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#matrix of features/ independant variables
x= dataset.drop(columns='Class')

# %%
#target variable/ dependant variable
y= dataset['Class']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train

# %%
x_train.shape
# Out:
# (227845, 30)

# %%
y_train

# %%
y_train.shape
# Out:
# (227845,)

# %%
x_test

# %%
x_test.shape
# Out:
# (56962, 30)

# %%
y_test

# %%
y_test.shape
# Out:
# (56962,)

# %% [markdown]
# ## feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# #Part 2: building the model

# %% [markdown]
# ##1. logistic regression

# %%
from sklearn.linear_model import LogisticRegression
classifier_lr = LogisticRegression(random_state=0)
classifier_lr.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier_lr.predict(x_test)

# %%
#to evaluate performace
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
acc= accuracy_score(y_test, y_pred)
print(acc*100)
# Out:
# 99.91924440855307

# %%
cm =  confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[56852     9]
#  [   37    64]]

# %% [markdown]
# # Part 3:Predicting a single observation

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
single_obs = [[0.0, -1.359807,	-0.072781	,2.536347,	1.378155,	-0.338321,
               0.462388,	0.239599,	0.098698,	0.363787,	0.090794,	-0.551600,
               -0.617801,	-0.991390,	-0.311169,	1.468177,	-0.470401,
               0.207971,	0.025791,	0.403993,	0.251412,	-0.018307,	0.277838,
               -0.110474,	0.066928,	0.128539,	-0.189115,	0.133558,	-0.021053,	149.62]]

# %%
classifier_lr.predict(sc.transform(single_obs))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([0])
